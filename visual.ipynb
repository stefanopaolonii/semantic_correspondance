# %%
# !python3 visualization_pairs.py \
  --model dinov2 \
  --model_arch vitb14 \
  --model_arch_tuned vitb14_ft2 \
  --dataset spair \
  --split test \
  --sample_idx 1644 \
  --match_method argmax \
  --match_method_tuned windowed_softargmax


# !python3 visualization_pairs.py \
  --model dinov3 \
  --model_arch vitb16 \
  --model_arch_tuned vitb16_ft4 \
  --dataset spair \
  --split test \
  --sample_idx 1644 \
  --match_method argmax \
  --match_method_tuned windowed_softargmax

# !python3 visualization_pairs.py \
  --model sam \
  --model_arch vitb16 \
  --model_arch_tuned vitb16_ft4 \
  --dataset spair \
  --split test \
  --sample_idx 1644 \
  --match_method argmax \
  --match_method_tuned windowed_softargmax  

# !python3 visualization_pairs.py \
  --model clip \
  --model_arch vitb16 \
  --model_arch_tuned vitb16_ft6 \
  --dataset spair \
  --split test \
  --resolution 512 \
  --sample_idx 1644 \
  --match_method argmax \
  --match_method_tuned windowed_softargmax
